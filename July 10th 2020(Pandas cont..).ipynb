# %%
import pandas as pd
info = pd.read_csv('data.csv')
info
# Out:
#        Name College          Course Branch  Year
# 0    Ambika                  Python    ECE  2017
# 1    Pavani   GITAM          Gaming    CSE  2017
# 2   Archana     GEC  Cyber Security    CSE  2016
# 3  Poojitha    VVIT                    ECE  2018
# 4    Ambika                  Python    ECE  2017
# 5    Pavani   GITAM          Gaming    CSE  2017
# 6   Archana     GEC  Cyber Security    CSE  2016
# 7  Poojitha    VVIT                    ECE  2018

# %%
info.head(2)
# Out:
#      Name College  Course Branch  Year
# 0  Ambika          Python    ECE  2017
# 1  Pavani   GITAM  Gaming    CSE  2017

# %%
info.tail(1)
# Out:
#        Name College Course Branch  Year
# 7  Poojitha    VVIT           ECE  2018

# %%
data = pd.read_csv('data.csv',usecols=['Name','Branch'])
data
# Out:
#        Name Branch
# 0    Ambika    ECE
# 1    Pavani    CSE
# 2   Archana    CSE
# 3  Poojitha    ECE
# 4    Ambika    ECE
# 5    Pavani    CSE
# 6   Archana    CSE
# 7  Poojitha    ECE

# %%
d = pd.read_csv('data.csv',header=None)
d
# Out:
#           0        1               2       3     4
# 0      Name  College          Course  Branch  Year
# 1    Ambika                   Python     ECE  2017
# 2    Pavani    GITAM          Gaming     CSE  2017
# 3   Archana      GEC  Cyber Security     CSE  2016
# 4  Poojitha     VVIT                     ECE  2018
# 5    Ambika                   Python     ECE  2017
# 6    Pavani    GITAM          Gaming     CSE  2017
# 7   Archana      GEC  Cyber Security     CSE  2016
# 8  Poojitha     VVIT                     ECE  2018

# %%
d1 = pd.read_csv('data.csv',names=['N','Col','C','B','Y'])
d1
# Out:
#           N      Col               C       B     Y
# 0      Name  College          Course  Branch  Year
# 1    Ambika                   Python     ECE  2017
# 2    Pavani    GITAM          Gaming     CSE  2017
# 3   Archana      GEC  Cyber Security     CSE  2016
# 4  Poojitha     VVIT                     ECE  2018
# 5    Ambika                   Python     ECE  2017
# 6    Pavani    GITAM          Gaming     CSE  2017
# 7   Archana      GEC  Cyber Security     CSE  2016
# 8  Poojitha     VVIT                     ECE  2018

# %%
info
# Out:
#        Name College          Course Branch  Year
# 0    Ambika                  Python    ECE  2017
# 1    Pavani   GITAM          Gaming    CSE  2017
# 2   Archana     GEC  Cyber Security    CSE  2016
# 3  Poojitha    VVIT                    ECE  2018
# 4    Ambika                  Python    ECE  2017
# 5    Pavani   GITAM          Gaming    CSE  2017
# 6   Archana     GEC  Cyber Security    CSE  2016
# 7  Poojitha    VVIT                    ECE  2018

# %%
info['College']
# Out:
# 0
# 1    GITAM
# 2      GEC
# 3     VVIT
# 4
# 5    GITAM
# 6      GEC
# 7     VVIT
# Name: College, dtype: object

# %%
info.columns
# Out:
# Index(['Name', 'College', 'Course', 'Branch', 'Year'], dtype='object')

# %%
info.info
# Out:
# <bound method DataFrame.info of        Name College          Course Branch  Year
# 0    Ambika                  Python    ECE  2017
# 1    Pavani   GITAM          Gaming    CSE  2017
# 2   Archana     GEC  Cyber Security    CSE  2016
# 3  Poojitha    VVIT                    ECE  2018
# 4    Ambika                  Python    ECE  2017
# 5    Pavani   GITAM          Gaming    CSE  2017
# 6   Archana     GEC  Cyber Security    CSE  2016
# 7  Poojitha    VVIT                    ECE  2018>

# %%
info.dtypes
# Out:
# Name       object
# College    object
# Course     object
# Branch     object
# Year        int64
# dtype: object

# %%
info.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
info.shape
# Out:
# (8, 5)

# %%
info.shape[0]
# Out:
# 8

# %%
info.shape[1]
# Out:
# 5

# %%
info
# Out:
#        Name College          Course Branch  Year
# 0    Ambika                  Python    ECE  2017
# 1    Pavani   GITAM          Gaming    CSE  2017
# 2   Archana     GEC  Cyber Security    CSE  2016
# 3  Poojitha    VVIT                    ECE  2018
# 4    Ambika                  Python    ECE  2017
# 5    Pavani   GITAM          Gaming    CSE  2017
# 6   Archana     GEC  Cyber Security    CSE  2016
# 7  Poojitha    VVIT                    ECE  2018

# %%
info.sort_values('Year',ascending=False)
# Out:
#        Name College          Course Branch  Year
# 3  Poojitha    VVIT                    ECE  2018
# 7  Poojitha    VVIT                    ECE  2018
# 0    Ambika                  Python    ECE  2017
# 1    Pavani   GITAM          Gaming    CSE  2017
# 4    Ambika                  Python    ECE  2017
# 5    Pavani   GITAM          Gaming    CSE  2017
# 2   Archana     GEC  Cyber Security    CSE  2016
# 6   Archana     GEC  Cyber Security    CSE  2016

# %%
info.sample(2)
# Out:
#        Name College  Course Branch  Year
# 1    Pavani   GITAM  Gaming    CSE  2017
# 3  Poojitha    VVIT            ECE  2018

# %%
info
# Out:
#        Name College          Course Branch  Year
# 0    Ambika                  Python    ECE  2017
# 1    Pavani   GITAM          Gaming    CSE  2017
# 2   Archana     GEC  Cyber Security    CSE  2016
# 3  Poojitha    VVIT                    ECE  2018
# 4    Ambika                  Python    ECE  2017
# 5    Pavani   GITAM          Gaming    CSE  2017
# 6   Archana     GEC  Cyber Security    CSE  2016
# 7  Poojitha    VVIT                    ECE  2018

# %%
info.dropna()
# Out:
#        Name College          Course Branch  Year
# 0    Ambika                  Python    ECE  2017
# 1    Pavani   GITAM          Gaming    CSE  2017
# 2   Archana     GEC  Cyber Security    CSE  2016
# 3  Poojitha    VVIT                    ECE  2018
# 4    Ambika                  Python    ECE  2017
# 5    Pavani   GITAM          Gaming    CSE  2017
# 6   Archana     GEC  Cyber Security    CSE  2016
# 7  Poojitha    VVIT                    ECE  2018

# %%
info1 = pd.read_csv('data.csv')
info1
# Out:
#        Name College          Course Branch  Year
# 0    Ambika                  Python    ECE  2017
# 1    Pavani   GITAM          Gaming    CSE  2017
# 2   Archana     GEC  Cyber Security    CSE  2016
# 3  Poojitha    VVIT                    ECE  2018
# 4    Ambika                  Python    ECE  2017
# 5    Pavani   GITAM          Gaming    CSE  2017
# 6   Archana     GEC  Cyber Security    CSE  2016
# 7  Poojitha    VVIT                    ECE  2018
# 8   Archana     GEC  Cyber Security    NaN  2016
# 9  Poojitha    VVIT             NaN    ECE  2018

# %%
info1.isnull()['Branch']
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9    False
# Name: Branch, dtype: bool

# %%
info1.nunique()
# Out:
# Name       4
# College    4
# Course     4
# Branch     2
# Year       3
# dtype: int64

# %%
info1.Branch.value_counts()
# Out:
# ECE    5
# CSE    4
# Name: Branch, dtype: int64
